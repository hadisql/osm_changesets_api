# %%
import json
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# #### Let's explore tags content for a sample of changesets

# %%
# First we run the fetch_and_process_changesets function locally
range_inf,range_sup = 6135330, 6135350
# !python manage.py shell -c \
    "from changesets.osm_fetcher import fetch_and_process_changesets; fetch_and_process_changesets({range_inf},{range_sup}, save_locally=True)"
# Out:
# /Users/hadi/Documents/coding/side_projects/osm_projects/osm_django_api/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Sequence 6135330 already processed.
# Sequence 6135331 already processed.
# Sequence 6135332 already processed.
# Sequence 6135333 already processed.
# Sequence 6135334 already processed.
# Sequence 6135335 already processed.
# Sequence 6135336 already processed.
# Sequence 6135337 already processed.
# Sequence 6135338 already processed.
# Sequence 6135339 already processed.
# Sequence 6135340 already processed.
# Sequence 6135341 already processed.
# Sequence 6135342 already processed.
# Sequence 6135343 already processed.
# Sequence 6135344 already processed.
# Sequence 6135345 already processed.
# Sequence 6135346 already processed.
# Sequence 6135347 already processed.
# Sequence 6135348 already processed.
# Sequence 6135349 already processed.
# Sequence 6135350 already processed.

# %% [markdown]
# #### We read the local data and save it in "all_data" variable

# %%
all_data = []
changesets = range(range_inf, range_sup)
# import .jsonl files from output directory
for i in changesets:
    with open(f'output/{i}.jsonl', 'r') as f:
        data = [json.loads(line) for line in f]
        all_data.extend(data)

# %%
len(all_data)
# Out:
# 1054

# %% [markdown]
# ### Number of unique tag keys:

# %%
def get_unique_tag_keys(data):
    set_ = set()
    for d in data:
        set_ = set_.union(set(d['tags'].keys()))
    return set_

print(len(get_unique_tag_keys(all_data)))
print(get_unique_tag_keys(all_data))
# Out:
# 56
# {'info:features_merged', 'resolved:close_nodes:vertices', 'warnings:almost_junction:highway-highway', 'host', 'warnings:mismatched_geometry:point_as_line', 'create', 'ideditor:walkthrough_started', 'fixing_osm_roads', 'locale', 'data_used', 'theme', 'warnings:suspicious_name:generic_name', 'ideditor:walkthrough_progress', 'closed:note', 'warnings:crossing_ways:building-highway', 'resolved:mismatched_geometry:line_as_vertex', 'warnings:outdated_tags:noncanonical_brand', 'warnings:crossing_ways:highway-waterway', 'resolved:crossing_ways:building-highway', 'bundle_id', 'resolved:outdated_tags:noncanonical_brand', 'hashtags', 'cases_where_human_help_is_required', 'warnings:disconnected_way:highway', 'resolved:crossing_ways:highway-highway', 'created_by', 'discussion_before_edits', 'bot', 'resolved:crossing_ways:highway-waterway', 'resolved:outdated_tags:deprecated_tags', 'ideditor:walkthrough_completed', 'imagery_used', 'resolved:mismatched_geometry:point_as_vertex', 'created_by:library', 'source', 'review_requested', 'changesets_count', 'created_by_library', 'warnings:missing_tag:descriptive', 'resolved:help_request:fixme_tag', 'StreetComplete:quest_type', 'resolved:crossing_ways:highway-railway', 'website', 'warnings:close_nodes:vertices', 'comment', 'answer', 'resolved:crossing_ways:building-building', 'resolved:outdated_tags:incomplete_tags', 'description', 'resolved:disconnected_way:highway', 'resolved:almost_junction:highway-highway', 'warnings:crossing_ways:building-building', 'osm_wiki_documentation_page', 'mechanical', 'resolved:mismatched_geometry:vertex_as_point', 'warnings:crossing_ways:highway-highway'}

# %% [markdown]
# ### Let's sum up all the unique tags in a DataFrame

# %%
all_tags = []
for data in all_data:
    all_tags.append(data['tags'])

df_tags = pd.DataFrame(all_tags)

df_tags.head(3)
# Out:
#                                              comment           created_by  \
# 0                              Specify parking types  StreetComplete 58.2
# 1   Specify whether public transport stops have bins  StreetComplete 58.2
# 2  Specify whether pedestrian crossings have islands  StreetComplete 58.2
#
#   locale  source StreetComplete:quest_type changesets_count host  \
# 0  de-DE  survey            AddParkingType              NaN  NaN
# 1  de-DE  survey     AddBinStatusOnBusStop              NaN  NaN
# 2  de-DE  survey         AddCrossingIsland              NaN  NaN
#
#   ideditor:walkthrough_completed ideditor:walkthrough_progress  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
#
#   ideditor:walkthrough_started  ... warnings:crossing_ways:building-building  \
# 0                          NaN  ...                                      NaN
# 1                          NaN  ...                                      NaN
# 2                          NaN  ...                                      NaN
#
#   resolved:crossing_ways:building-highway  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
#
#   resolved:crossing_ways:highway-railway created_by:library website answer  \
# 0                                    NaN                NaN     NaN    NaN
# 1                                    NaN                NaN     NaN    NaN
# 2                                    NaN                NaN     NaN    NaN
#
#   warnings:close_nodes:vertices resolved:crossing_ways:highway-highway  \
# 0                           NaN                                    NaN
# 1                           NaN                                    NaN
# 2                           NaN                                    NaN
#
#   warnings:outdated_tags:noncanonical_brand  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
#
#   resolved:crossing_ways:building-building
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
#
# [3 rows x 56 columns]

# %% [markdown]
# ### Number of unique values per tag ?
# #### (less unique values makes the tag a good candidate for becoming a Changeset model attribute)

# %%
df_uniques = pd.DataFrame(df_tags.nunique()).reset_index().rename(columns={'index': 'tag', 0: 'unique_values'})
df_uniques
# Out:
#                                              tag  unique_values
# 0                                        comment            543
# 1                                     created_by             73
# 2                                         locale             47
# 3                                         source             99
# 4                      StreetComplete:quest_type            111
# 5                               changesets_count            322
# 6                                           host             13
# 7                 ideditor:walkthrough_completed              1
# 8                  ideditor:walkthrough_progress              8
# 9                   ideditor:walkthrough_started              1
# 10                                  imagery_used             73
# 11                                      hashtags             37
# 12      resolved:almost_junction:highway-highway              1
# 13                                     data_used              2
# 14               resolved:help_request:fixme_tag              1
# 15  resolved:mismatched_geometry:point_as_vertex              1
# 16        resolved:outdated_tags:incomplete_tags              4
# 17     resolved:outdated_tags:noncanonical_brand              4
# 18                 resolved:close_nodes:vertices              1
# 19       warnings:crossing_ways:highway-waterway              2
# 20              warnings:missing_tag:descriptive              1
# 21                                     bundle_id              1
# 22       warnings:crossing_ways:building-highway              1
# 23             warnings:disconnected_way:highway              3
# 24                                   closed:note              1
# 25      warnings:almost_junction:highway-highway              1
# 26                              fixing_osm_roads              1
# 27                                           bot              1
# 28            cases_where_human_help_is_required              1
# 29                            created_by_library              1
# 30                       discussion_before_edits              1
# 31                                    mechanical              1
# 32                   osm_wiki_documentation_page              1
# 33                              review_requested              1
# 34                                   description              1
# 35                                        create              1
# 36                                         theme              2
# 37       resolved:crossing_ways:highway-waterway              2
# 38        resolved:outdated_tags:deprecated_tags              1
# 39                          info:features_merged              1
# 40         warnings:suspicious_name:generic_name              1
# 41   resolved:mismatched_geometry:line_as_vertex              1
# 42  resolved:mismatched_geometry:vertex_as_point              2
# 43        warnings:crossing_ways:highway-highway              2
# 44             resolved:disconnected_way:highway              1
# 45    warnings:mismatched_geometry:point_as_line              1
# 46      warnings:crossing_ways:building-building              1
# 47       resolved:crossing_ways:building-highway              3
# 48        resolved:crossing_ways:highway-railway              1
# 49                            created_by:library              1
# 50                                       website              1
# 51                                        answer              1
# 52                 warnings:close_nodes:vertices              1
# 53        resolved:crossing_ways:highway-highway              1
# 54     warnings:outdated_tags:noncanonical_brand              1
# 55      resolved:crossing_ways:building-building              1

# %%
df_tags['hashtags'].unique()
# Out:
# array([nan, '#hotosm-project-16817;#UNMappers;#UNMOGIP;#Jammu;#Kashmir',
#        '#geohealthresearch-project-26;#PivotscienceActivity', '#ola;#rdv',
#        '#irsju', '#hotosm-project-16875;#GeOSM;#PUC', '#adt',
#        '#hotosm-project-17137;#bloomberg;#emea',
#        '#hotosm-project-15229;#OSMIndia;#OSMNorthEastIndia;#GREd;#GREdFoundation;#AssamMapping23;#OMGuru;#APHub;#CCC2024;#tt_event',
#        '#BANO;#Pifometre', '#amap', '#tomtom;#tt_mapfeedback',
#        '#hotosm-project-14389;#MangochiDistrict;#msf;#missingmaps;#malawicholeraoutbreak',
#        '#maproulette', '#OpenCampingMap', '#lgmaps', '#swiggy',
#        '#PUC;#EST;#tt_event',
#        '#hotosm-project-15188;#Ndjamena;#msf;#missingmaps;#Ndjamena2023;#Msft;#24VR',
#        '#localknowledge;#grabosm',
#        '#hotosm-project-16259;#osmTaiwan;#NLSCopendata;#rivertracing',
#        '#MSFTOpenMaps',
#        '#hotosm-project-17266;#UPMAPPERS;#WAFARI;#YouthMappers;#SouthAfrica;#ESADisasterResponse',
#        '#maproulette;#tomtom', '#mapbox_linters', '#ola;#evf',
#        '#hotosm-project-17320;#ESC2023;#WNAH;#HOT;#Map4CIV;#OSM20th;#osmGambia;#osmghana;#mapnigeria;#Map4Sn;#Map4NE;#humatarian-mappers',
#        '#tomtom',
#        '#hotosm-project-15008;#Tandjile;#msf;#missingmaps;#Tandjile2023',
#        '#ola;#2xrdv', '#wbgeo', '#ola;#qcr',
#        '#hotosm-project-17137;#bloomberg', '#کفش_کودک;#ninipa;#shoes',
#        '#geoventurersFSU;#UnmappedSmallTownUSA', '#Pic4Review',
#        '#grabosm',
#        '#hotosm-project-16836;#ESAOMG2024;#GeoConnect;#ChinhoyiMunicipality;#OSMZimbabwe;#ChinhoyiOpenMapping;#Cutgeospatialsociety'],
#       dtype=object)

# %% [markdown]
# ### For the "unique" unique values (=1), what are they for each key ?

# %%
# list of tags with only 1 unique value
l_1 = list(df_uniques['tag'][df_uniques['unique_values'] == 1])
l_1[-5:] # last five
# Out:
# ['answer',
#  'warnings:close_nodes:vertices',
#  'resolved:crossing_ways:highway-highway',
#  'warnings:outdated_tags:noncanonical_brand',
#  'resolved:crossing_ways:building-building']

# %%
df_tags['create'][~df_tags['create'].isna()]
# Out:
# 352    1
# 838    1
# Name: create, dtype: object

# %%
# show df for lines 352 and 838 : two changesets concerned by the same tag (NaN for all other changesets)
df_tags.iloc[[352,838]].T
# Out:
#                                                                                             352  \
# comment                                       Adding data with #MapComplete for theme #ghost...
# created_by                                                                  MapComplete 0.44.13
# locale                                                                                    de-DE
# source                                                                                      NaN
# StreetComplete:quest_type                                                                   NaN
# changesets_count                                                                            NaN
# host                                                    https://mapcomplete.org/ghostbikes.html
# ideditor:walkthrough_completed                                                              NaN
# ideditor:walkthrough_progress                                                               NaN
# ideditor:walkthrough_started                                                                NaN
# imagery_used                                                                                NaN
# hashtags                                                                                    NaN
# resolved:almost_junction:highway-highway                                                    NaN
# data_used                                                                                   NaN
# resolved:help_request:fixme_tag                                                             NaN
# resolved:mismatched_geometry:point_as_vertex                                                NaN
# resolved:outdated_tags:incomplete_tags                                                      NaN
# resolved:outdated_tags:noncanonical_brand                                                   NaN
# resolved:close_nodes:vertices                                                               NaN
# warnings:crossing_ways:highway-waterway                                                     NaN
# warnings:missing_tag:descriptive                                                            NaN
# bundle_id                                                                                   NaN
# warnings:crossing_ways:building-highway                                                     NaN
# warnings:disconnected_way:highway                                                           NaN
# closed:note                                                                                 NaN
# warnings:almost_junction:highway-highway                                                    NaN
# fixing_osm_roads                                                                            NaN
# bot                                                                                         NaN
# cases_where_human_help_is_required                                                          NaN
# created_by_library                                                                          NaN
# discussion_before_edits                                                                     NaN
# mechanical                                                                                  NaN
# osm_wiki_documentation_page                                                                 NaN
# review_requested                                                                            NaN
# description                                                                                 NaN
# create                                                                                        1
# theme                                                                                ghostbikes
# resolved:crossing_ways:highway-waterway                                                     NaN
# resolved:outdated_tags:deprecated_tags                                                      NaN
# info:features_merged                                                                        NaN
# warnings:suspicious_name:generic_name                                                       NaN
# resolved:mismatched_geometry:line_as_vertex                                                 NaN
# resolved:mismatched_geometry:vertex_as_point                                                NaN
# warnings:crossing_ways:highway-highway                                                      NaN
# resolved:disconnected_way:highway                                                           NaN
# warnings:mismatched_geometry:point_as_line                                                  NaN
# warnings:crossing_ways:building-building                                                    NaN
# resolved:crossing_ways:building-highway                                                     NaN
# resolved:crossing_ways:highway-railway                                                      NaN
# created_by:library                                                                          NaN
# website                                                                                     NaN
# answer                                                                                      NaN
# warnings:close_nodes:vertices                                                               NaN
# resolved:crossing_ways:highway-highway                                                      NaN
# warnings:outdated_tags:noncanonical_brand                                                   NaN
# resolved:crossing_ways:building-building                                                    NaN
#
#                                                                                           838
# comment                                       Adding data with #MapComplete for theme #hotels
# created_by                                                                MapComplete 0.44.13
# locale                                                                                     en
# source                                                                                    NaN
# StreetComplete:quest_type                                                                 NaN
# changesets_count                                                                          NaN
# host                                                      https://mapcomplete.org/hotels.html
# ideditor:walkthrough_completed                                                            NaN
# ideditor:walkthrough_progress                                                             NaN
# ideditor:walkthrough_started                                                              NaN
# imagery_used                                                                              NaN
# hashtags                                                                                  NaN
# resolved:almost_junction:highway-highway                                                  NaN
# data_used                                                                                 NaN
# resolved:help_request:fixme_tag                                                           NaN
# resolved:mismatched_geometry:point_as_vertex                                              NaN
# resolved:outdated_tags:incomplete_tags                                                    NaN
# resolved:outdated_tags:noncanonical_brand                                                 NaN
# resolved:close_nodes:vertices                                                             NaN
# warnings:crossing_ways:highway-waterway                                                   NaN
# warnings:missing_tag:descriptive                                                          NaN
# bundle_id                                                                                 NaN
# warnings:crossing_ways:building-highway                                                   NaN
# warnings:disconnected_way:highway                                                         NaN
# closed:note                                                                               NaN
# warnings:almost_junction:highway-highway                                                  NaN
# fixing_osm_roads                                                                          NaN
# bot                                                                                       NaN
# cases_where_human_help_is_required                                                        NaN
# created_by_library                                                                        NaN
# discussion_before_edits                                                                   NaN
# mechanical                                                                                NaN
# osm_wiki_documentation_page                                                               NaN
# review_requested                                                                          NaN
# description                                                                               NaN
# create                                                                                      1
# theme                                                                                  hotels
# resolved:crossing_ways:highway-waterway                                                   NaN
# resolved:outdated_tags:deprecated_tags                                                    NaN
# info:features_merged                                                                      NaN
# warnings:suspicious_name:generic_name                                                     NaN
# resolved:mismatched_geometry:line_as_vertex                                               NaN
# resolved:mismatched_geometry:vertex_as_point                                              NaN
# warnings:crossing_ways:highway-highway                                                    NaN
# resolved:disconnected_way:highway                                                         NaN
# warnings:mismatched_geometry:point_as_line                                                NaN
# warnings:crossing_ways:building-building                                                  NaN
# resolved:crossing_ways:building-highway                                                   NaN
# resolved:crossing_ways:highway-railway                                                    NaN
# created_by:library                                                                        NaN
# website                                                                                   NaN
# answer                                                                                    NaN
# warnings:close_nodes:vertices                                                             NaN
# resolved:crossing_ways:highway-highway                                                    NaN
# warnings:outdated_tags:noncanonical_brand                                                 NaN
# resolved:crossing_ways:building-building                                                  NaN

# %%
df_tags['description'].value_counts().rename_axis('unique_values').reset_index(name='count')
# Out:
#                                        unique_values  count
# 0  https://wiki.openstreetmap.org/wiki/Automated_...      2

# %% [markdown]
# ### DataFrame that sums up the occurrence of each unique uniques (unique values == 1)

# %%
df_tags[l_1].apply(pd.Series.value_counts).rename_axis('unique unique_values').T
# Out:
# unique unique_values                            1   10    2  3820706    4  \
# ideditor:walkthrough_completed                NaN  NaN  NaN      NaN  NaN
# ideditor:walkthrough_started                  NaN  NaN  NaN      NaN  NaN
# resolved:almost_junction:highway-highway      1.0  NaN  NaN      NaN  NaN
# resolved:help_request:fixme_tag               3.0  NaN  NaN      NaN  NaN
# resolved:mismatched_geometry:point_as_vertex  2.0  NaN  NaN      NaN  NaN
# resolved:close_nodes:vertices                 NaN  NaN  1.0      NaN  NaN
# warnings:missing_tag:descriptive              1.0  NaN  NaN      NaN  NaN
# bundle_id                                     NaN  NaN  NaN      NaN  NaN
# warnings:crossing_ways:building-highway       1.0  NaN  NaN      NaN  NaN
# closed:note                                   NaN  NaN  NaN      1.0  NaN
# warnings:almost_junction:highway-highway      3.0  NaN  NaN      NaN  NaN
# fixing_osm_roads                              NaN  NaN  NaN      NaN  NaN
# bot                                           NaN  NaN  NaN      NaN  NaN
# cases_where_human_help_is_required            NaN  NaN  NaN      NaN  NaN
# created_by_library                            NaN  NaN  NaN      NaN  NaN
# discussion_before_edits                       NaN  NaN  NaN      NaN  NaN
# mechanical                                    NaN  NaN  NaN      NaN  NaN
# osm_wiki_documentation_page                   NaN  NaN  NaN      NaN  NaN
# review_requested                              NaN  NaN  NaN      NaN  NaN
# description                                   NaN  NaN  NaN      NaN  NaN
# create                                        2.0  NaN  NaN      NaN  NaN
# resolved:outdated_tags:deprecated_tags        1.0  NaN  NaN      NaN  NaN
# info:features_merged                          NaN  NaN  NaN      NaN  NaN
# warnings:suspicious_name:generic_name         1.0  NaN  NaN      NaN  NaN
# resolved:mismatched_geometry:line_as_vertex   NaN  NaN  NaN      NaN  1.0
# resolved:disconnected_way:highway             2.0  NaN  NaN      NaN  NaN
# warnings:mismatched_geometry:point_as_line    1.0  NaN  NaN      NaN  NaN
# warnings:crossing_ways:building-building      3.0  NaN  NaN      NaN  NaN
# resolved:crossing_ways:highway-railway        NaN  NaN  1.0      NaN  NaN
# created_by:library                            NaN  NaN  NaN      NaN  NaN
# website                                       NaN  NaN  NaN      NaN  NaN
# answer                                        2.0  NaN  NaN      NaN  NaN
# warnings:close_nodes:vertices                 1.0  NaN  NaN      NaN  NaN
# resolved:crossing_ways:highway-highway        NaN  1.0  NaN      NaN  NaN
# warnings:outdated_tags:noncanonical_brand     1.0  NaN  NaN      NaN  NaN
# resolved:crossing_ways:building-building      NaN  NaN  NaN      NaN  NaN
#
# unique unique_values                            6  OSM Request 1.2.9  alias8  \
# ideditor:walkthrough_completed                NaN                NaN     NaN
# ideditor:walkthrough_started                  NaN                NaN     NaN
# resolved:almost_junction:highway-highway      NaN                NaN     NaN
# resolved:help_request:fixme_tag               NaN                NaN     NaN
# resolved:mismatched_geometry:point_as_vertex  NaN                NaN     NaN
# resolved:close_nodes:vertices                 NaN                NaN     NaN
# warnings:missing_tag:descriptive              NaN                NaN     NaN
# bundle_id                                     NaN                NaN     NaN
# warnings:crossing_ways:building-highway       NaN                NaN     NaN
# closed:note                                   NaN                NaN     NaN
# warnings:almost_junction:highway-highway      NaN                NaN     NaN
# fixing_osm_roads                              NaN                NaN     1.0
# bot                                           NaN                NaN     NaN
# cases_where_human_help_is_required            NaN                NaN     NaN
# created_by_library                            NaN                NaN     NaN
# discussion_before_edits                       NaN                NaN     NaN
# mechanical                                    NaN                NaN     NaN
# osm_wiki_documentation_page                   NaN                NaN     NaN
# review_requested                              NaN                NaN     NaN
# description                                   NaN                NaN     NaN
# create                                        NaN                NaN     NaN
# resolved:outdated_tags:deprecated_tags        NaN                NaN     NaN
# info:features_merged                          NaN                NaN     NaN
# warnings:suspicious_name:generic_name         NaN                NaN     NaN
# resolved:mismatched_geometry:line_as_vertex   NaN                NaN     NaN
# resolved:disconnected_way:highway             NaN                NaN     NaN
# warnings:mismatched_geometry:point_as_line    NaN                NaN     NaN
# warnings:crossing_ways:building-building      NaN                NaN     NaN
# resolved:crossing_ways:highway-railway        NaN                NaN     NaN
# created_by:library                            NaN                1.0     NaN
# website                                       NaN                NaN     NaN
# answer                                        NaN                NaN     NaN
# warnings:close_nodes:vertices                 NaN                NaN     NaN
# resolved:crossing_ways:highway-highway        NaN                NaN     NaN
# warnings:outdated_tags:noncanonical_brand     NaN                NaN     NaN
# resolved:crossing_ways:building-building      1.0                NaN     NaN
#
# unique unique_values                          app.organicmaps  \
# ideditor:walkthrough_completed                            NaN
# ideditor:walkthrough_started                              NaN
# resolved:almost_junction:highway-highway                  NaN
# resolved:help_request:fixme_tag                           NaN
# resolved:mismatched_geometry:point_as_vertex              NaN
# resolved:close_nodes:vertices                             NaN
# warnings:missing_tag:descriptive                          NaN
# bundle_id                                                 7.0
# warnings:crossing_ways:building-highway                   NaN
# closed:note                                               NaN
# warnings:almost_junction:highway-highway                  NaN
# fixing_osm_roads                                          NaN
# bot                                                       NaN
# cases_where_human_help_is_required                        NaN
# created_by_library                                        NaN
# discussion_before_edits                                   NaN
# mechanical                                                NaN
# osm_wiki_documentation_page                               NaN
# review_requested                                          NaN
# description                                               NaN
# create                                                    NaN
# resolved:outdated_tags:deprecated_tags                    NaN
# info:features_merged                                      NaN
# warnings:suspicious_name:generic_name                     NaN
# resolved:mismatched_geometry:line_as_vertex               NaN
# resolved:disconnected_way:highway                         NaN
# warnings:mismatched_geometry:point_as_line                NaN
# warnings:crossing_ways:building-building                  NaN
# resolved:crossing_ways:highway-railway                    NaN
# created_by:library                                        NaN
# website                                                   NaN
# answer                                                    NaN
# warnings:close_nodes:vertices                             NaN
# resolved:crossing_ways:highway-highway                    NaN
# warnings:outdated_tags:noncanonical_brand                 NaN
# resolved:crossing_ways:building-building                  NaN
#
# unique unique_values                          https://community.openstreetmap.org/t/mass-remove-gnis-created-and-similar-tags/107018  \
# ideditor:walkthrough_completed                                                              NaN
# ideditor:walkthrough_started                                                                NaN
# resolved:almost_junction:highway-highway                                                    NaN
# resolved:help_request:fixme_tag                                                             NaN
# resolved:mismatched_geometry:point_as_vertex                                                NaN
# resolved:close_nodes:vertices                                                               NaN
# warnings:missing_tag:descriptive                                                            NaN
# bundle_id                                                                                   NaN
# warnings:crossing_ways:building-highway                                                     NaN
# closed:note                                                                                 NaN
# warnings:almost_junction:highway-highway                                                    NaN
# fixing_osm_roads                                                                            NaN
# bot                                                                                         NaN
# cases_where_human_help_is_required                                                          NaN
# created_by_library                                                                          NaN
# discussion_before_edits                                                                     2.0
# mechanical                                                                                  NaN
# osm_wiki_documentation_page                                                                 NaN
# review_requested                                                                            NaN
# description                                                                                 NaN
# create                                                                                      NaN
# resolved:outdated_tags:deprecated_tags                                                      NaN
# info:features_merged                                                                        NaN
# warnings:suspicious_name:generic_name                                                       NaN
# resolved:mismatched_geometry:line_as_vertex                                                 NaN
# resolved:disconnected_way:highway                                                           NaN
# warnings:mismatched_geometry:point_as_line                                                  NaN
# warnings:crossing_ways:building-building                                                    NaN
# resolved:crossing_ways:highway-railway                                                      NaN
# created_by:library                                                                          NaN
# website                                                                                     NaN
# answer                                                                                      NaN
# warnings:close_nodes:vertices                                                               NaN
# resolved:crossing_ways:highway-highway                                                      NaN
# warnings:outdated_tags:noncanonical_brand                                                   NaN
# resolved:crossing_ways:building-building                                                    NaN
#
# unique unique_values                          https://github.com/matkoniecz/osm_bot_abstraction_layer  \
# ideditor:walkthrough_completed                                                              NaN
# ideditor:walkthrough_started                                                                NaN
# resolved:almost_junction:highway-highway                                                    NaN
# resolved:help_request:fixme_tag                                                             NaN
# resolved:mismatched_geometry:point_as_vertex                                                NaN
# resolved:close_nodes:vertices                                                               NaN
# warnings:missing_tag:descriptive                                                            NaN
# bundle_id                                                                                   NaN
# warnings:crossing_ways:building-highway                                                     NaN
# closed:note                                                                                 NaN
# warnings:almost_junction:highway-highway                                                    NaN
# fixing_osm_roads                                                                            NaN
# bot                                                                                         NaN
# cases_where_human_help_is_required                                                          NaN
# created_by_library                                                                          2.0
# discussion_before_edits                                                                     NaN
# mechanical                                                                                  NaN
# osm_wiki_documentation_page                                                                 NaN
# review_requested                                                                            NaN
# description                                                                                 NaN
# create                                                                                      NaN
# resolved:outdated_tags:deprecated_tags                                                      NaN
# info:features_merged                                                                        NaN
# warnings:suspicious_name:generic_name                                                       NaN
# resolved:mismatched_geometry:line_as_vertex                                                 NaN
# resolved:disconnected_way:highway                                                           NaN
# warnings:mismatched_geometry:point_as_line                                                  NaN
# warnings:crossing_ways:building-building                                                    NaN
# resolved:crossing_ways:highway-railway                                                      NaN
# created_by:library                                                                          NaN
# website                                                                                     NaN
# answer                                                                                      NaN
# warnings:close_nodes:vertices                                                               NaN
# resolved:crossing_ways:highway-highway                                                      NaN
# warnings:outdated_tags:noncanonical_brand                                                   NaN
# resolved:crossing_ways:building-building                                                    NaN
#
# unique unique_values                          https://matkoniecz.github.io/OSM-wikipedia-tag-validator-reports/  \
# ideditor:walkthrough_completed                                                              NaN
# ideditor:walkthrough_started                                                                NaN
# resolved:almost_junction:highway-highway                                                    NaN
# resolved:help_request:fixme_tag                                                             NaN
# resolved:mismatched_geometry:point_as_vertex                                                NaN
# resolved:close_nodes:vertices                                                               NaN
# warnings:missing_tag:descriptive                                                            NaN
# bundle_id                                                                                   NaN
# warnings:crossing_ways:building-highway                                                     NaN
# closed:note                                                                                 NaN
# warnings:almost_junction:highway-highway                                                    NaN
# fixing_osm_roads                                                                            NaN
# bot                                                                                         NaN
# cases_where_human_help_is_required                                                          2.0
# created_by_library                                                                          NaN
# discussion_before_edits                                                                     NaN
# mechanical                                                                                  NaN
# osm_wiki_documentation_page                                                                 NaN
# review_requested                                                                            NaN
# description                                                                                 NaN
# create                                                                                      NaN
# resolved:outdated_tags:deprecated_tags                                                      NaN
# info:features_merged                                                                        NaN
# warnings:suspicious_name:generic_name                                                       NaN
# resolved:mismatched_geometry:line_as_vertex                                                 NaN
# resolved:disconnected_way:highway                                                           NaN
# warnings:mismatched_geometry:point_as_line                                                  NaN
# warnings:crossing_ways:building-building                                                    NaN
# resolved:crossing_ways:highway-railway                                                      NaN
# created_by:library                                                                          NaN
# website                                                                                     NaN
# answer                                                                                      NaN
# warnings:close_nodes:vertices                                                               NaN
# resolved:crossing_ways:highway-highway                                                      NaN
# warnings:outdated_tags:noncanonical_brand                                                   NaN
# resolved:crossing_ways:building-building                                                    NaN
#
# unique unique_values                          https://pic4review.pavie.info/#/mission/2732/review  \
# ideditor:walkthrough_completed                                                              NaN
# ideditor:walkthrough_started                                                                NaN
# resolved:almost_junction:highway-highway                                                    NaN
# resolved:help_request:fixme_tag                                                             NaN
# resolved:mismatched_geometry:point_as_vertex                                                NaN
# resolved:close_nodes:vertices                                                               NaN
# warnings:missing_tag:descriptive                                                            NaN
# bundle_id                                                                                   NaN
# warnings:crossing_ways:building-highway                                                     NaN
# closed:note                                                                                 NaN
# warnings:almost_junction:highway-highway                                                    NaN
# fixing_osm_roads                                                                            NaN
# bot                                                                                         NaN
# cases_where_human_help_is_required                                                          NaN
# created_by_library                                                                          NaN
# discussion_before_edits                                                                     NaN
# mechanical                                                                                  NaN
# osm_wiki_documentation_page                                                                 NaN
# review_requested                                                                            NaN
# description                                                                                 NaN
# create                                                                                      NaN
# resolved:outdated_tags:deprecated_tags                                                      NaN
# info:features_merged                                                                        NaN
# warnings:suspicious_name:generic_name                                                       NaN
# resolved:mismatched_geometry:line_as_vertex                                                 NaN
# resolved:disconnected_way:highway                                                           NaN
# warnings:mismatched_geometry:point_as_line                                                  NaN
# warnings:crossing_ways:building-building                                                    NaN
# resolved:crossing_ways:highway-railway                                                      NaN
# created_by:library                                                                          NaN
# website                                                                                     1.0
# answer                                                                                      NaN
# warnings:close_nodes:vertices                                                               NaN
# resolved:crossing_ways:highway-highway                                                      NaN
# warnings:outdated_tags:noncanonical_brand                                                   NaN
# resolved:crossing_ways:building-building                                                    NaN
#
# unique unique_values                          https://wiki.openstreetmap.org/wiki/Automated_Edits/b-jazz  \
# ideditor:walkthrough_completed                                                              NaN
# ideditor:walkthrough_started                                                                NaN
# resolved:almost_junction:highway-highway                                                    NaN
# resolved:help_request:fixme_tag                                                             NaN
# resolved:mismatched_geometry:point_as_vertex                                                NaN
# resolved:close_nodes:vertices                                                               NaN
# warnings:missing_tag:descriptive                                                            NaN
# bundle_id                                                                                   NaN
# warnings:crossing_ways:building-highway                                                     NaN
# closed:note                                                                                 NaN
# warnings:almost_junction:highway-highway                                                    NaN
# fixing_osm_roads                                                                            NaN
# bot                                                                                         NaN
# cases_where_human_help_is_required                                                          NaN
# created_by_library                                                                          NaN
# discussion_before_edits                                                                     NaN
# mechanical                                                                                  NaN
# osm_wiki_documentation_page                                                                 NaN
# review_requested                                                                            NaN
# description                                                                                 2.0
# create                                                                                      NaN
# resolved:outdated_tags:deprecated_tags                                                      NaN
# info:features_merged                                                                        NaN
# warnings:suspicious_name:generic_name                                                       NaN
# resolved:mismatched_geometry:line_as_vertex                                                 NaN
# resolved:disconnected_way:highway                                                           NaN
# warnings:mismatched_geometry:point_as_line                                                  NaN
# warnings:crossing_ways:building-building                                                    NaN
# resolved:crossing_ways:highway-railway                                                      NaN
# created_by:library                                                                          NaN
# website                                                                                     NaN
# answer                                                                                      NaN
# warnings:close_nodes:vertices                                                               NaN
# resolved:crossing_ways:highway-highway                                                      NaN
# warnings:outdated_tags:noncanonical_brand                                                   NaN
# resolved:crossing_ways:building-building                                                    NaN
#
# unique unique_values                          https://wiki.openstreetmap.org/wiki/Mechanical_Edits/Mateusz_Konieczny_-_bot_account/remove_not_needed_GNIS_tags  \
# ideditor:walkthrough_completed                                                              NaN
# ideditor:walkthrough_started                                                                NaN
# resolved:almost_junction:highway-highway                                                    NaN
# resolved:help_request:fixme_tag                                                             NaN
# resolved:mismatched_geometry:point_as_vertex                                                NaN
# resolved:close_nodes:vertices                                                               NaN
# warnings:missing_tag:descriptive                                                            NaN
# bundle_id                                                                                   NaN
# warnings:crossing_ways:building-highway                                                     NaN
# closed:note                                                                                 NaN
# warnings:almost_junction:highway-highway                                                    NaN
# fixing_osm_roads                                                                            NaN
# bot                                                                                         NaN
# cases_where_human_help_is_required                                                          NaN
# created_by_library                                                                          NaN
# discussion_before_edits                                                                     NaN
# mechanical                                                                                  NaN
# osm_wiki_documentation_page                                                                 2.0
# review_requested                                                                            NaN
# description                                                                                 NaN
# create                                                                                      NaN
# resolved:outdated_tags:deprecated_tags                                                      NaN
# info:features_merged                                                                        NaN
# warnings:suspicious_name:generic_name                                                       NaN
# resolved:mismatched_geometry:line_as_vertex                                                 NaN
# resolved:disconnected_way:highway                                                           NaN
# warnings:mismatched_geometry:point_as_line                                                  NaN
# warnings:crossing_ways:building-building                                                    NaN
# resolved:crossing_ways:highway-railway                                                      NaN
# created_by:library                                                                          NaN
# website                                                                                     NaN
# answer                                                                                      NaN
# warnings:close_nodes:vertices                                                               NaN
# resolved:crossing_ways:highway-highway                                                      NaN
# warnings:outdated_tags:noncanonical_brand                                                   NaN
# resolved:crossing_ways:building-building                                                    NaN
#
# unique unique_values                           yes
# ideditor:walkthrough_completed                 3.0
# ideditor:walkthrough_started                  24.0
# resolved:almost_junction:highway-highway       NaN
# resolved:help_request:fixme_tag                NaN
# resolved:mismatched_geometry:point_as_vertex   NaN
# resolved:close_nodes:vertices                  NaN
# warnings:missing_tag:descriptive               NaN
# bundle_id                                      NaN
# warnings:crossing_ways:building-highway        NaN
# closed:note                                    NaN
# warnings:almost_junction:highway-highway       NaN
# fixing_osm_roads                               NaN
# bot                                            4.0
# cases_where_human_help_is_required             NaN
# created_by_library                             NaN
# discussion_before_edits                        NaN
# mechanical                                     2.0
# osm_wiki_documentation_page                    NaN
# review_requested                              12.0
# description                                    NaN
# create                                         NaN
# resolved:outdated_tags:deprecated_tags         NaN
# info:features_merged                           1.0
# warnings:suspicious_name:generic_name          NaN
# resolved:mismatched_geometry:line_as_vertex    NaN
# resolved:disconnected_way:highway              NaN
# warnings:mismatched_geometry:point_as_line     NaN
# warnings:crossing_ways:building-building       NaN
# resolved:crossing_ways:highway-railway         NaN
# created_by:library                             NaN
# website                                        NaN
# answer                                         NaN
# warnings:close_nodes:vertices                  NaN
# resolved:crossing_ways:highway-highway         NaN
# warnings:outdated_tags:noncanonical_brand      NaN
# resolved:crossing_ways:building-building       NaN
