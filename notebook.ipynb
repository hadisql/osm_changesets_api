# %%
import json
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# #### Let's explore tags content for a sample of changesets

# %%
# First we run the fetch_and_process_changesets function locally
range_inf,range_sup = 6135330, 6135350
# !python manage.py shell -c \
    "from changesets.osm_fetcher import fetch_and_process_changesets; fetch_and_process_changesets({range_inf},{range_sup}, save_locally=True)"
# Out:
# /Users/hadi/Documents/coding/side_projects/osm_projects/osm_django_api/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Sequence 6135330 already processed.
# Sequence 6135331 already processed.
# Sequence 6135332 already processed.
# Sequence 6135333 already processed.
# Sequence 6135334 already processed.
# Sequence 6135335 already processed.
# Sequence 6135336 already processed.
# Sequence 6135337 already processed.
# Sequence 6135338 already processed.
# Sequence 6135339 already processed.
# Sequence 6135340 already processed.
# Sequence 6135341 already processed.
# Sequence 6135342 already processed.
# Sequence 6135343 already processed.
# Sequence 6135344 already processed.
# Sequence 6135345 already processed.
# Sequence 6135346 already processed.
# ...

# %% [markdown]
# #### We read the local data and save it in "all_data" variable

# %%
all_data = []
changesets = range(range_inf, range_sup)
# import .jsonl files from output directory
for i in changesets:
    with open(f'output/{i}.jsonl', 'r') as f:
        data = [json.loads(line) for line in f]
        all_data.extend(data)

# %%
len(all_data)
# Out:
# 1054

# %% [markdown]
# ### Number of unique tag keys:

# %%
def get_unique_tag_keys(data):
    set_ = set()
    for d in data:
        set_ = set_.union(set(d['tags'].keys()))
    return set_

print(len(get_unique_tag_keys(all_data)))
print(get_unique_tag_keys(all_data))
# Out:
# 56
# ...

# %% [markdown]
# ### Let's sum up all the unique tags in a DataFrame

# %%
all_tags = []
for data in all_data:
    all_tags.append(data['tags'])

df_tags = pd.DataFrame(all_tags)

df_tags.head(3)
# Out:
#                                              comment           created_by  \
# 0                              Specify parking types  StreetComplete 58.2
# 1   Specify whether public transport stops have bins  StreetComplete 58.2
# 2  Specify whether pedestrian crossings have islands  StreetComplete 58.2
#
#   locale  source StreetComplete:quest_type changesets_count host  \
# 0  de-DE  survey            AddParkingType              NaN  NaN
# 1  de-DE  survey     AddBinStatusOnBusStop              NaN  NaN
# 2  de-DE  survey         AddCrossingIsland              NaN  NaN
#
#   ideditor:walkthrough_completed ideditor:walkthrough_progress  \
# 0                            NaN                           NaN
# 1                            NaN                           NaN
# 2                            NaN                           NaN
#
#   ideditor:walkthrough_started  ... warnings:crossing_ways:building-building  \
# ...

# %% [markdown]
# ### Number of unique values per tag ?
# #### (less unique values makes the tag a good candidate for becoming a Changeset model attribute)

# %%
df_uniques = pd.DataFrame(df_tags.nunique()).reset_index().rename(columns={'index': 'tag', 0: 'unique_values'})
df_uniques
# Out:
#                                              tag  unique_values
# 0                                        comment            543
# 1                                     created_by             73
# 2                                         locale             47
# 3                                         source             99
# 4                      StreetComplete:quest_type            111
# 5                               changesets_count            322
# 6                                           host             13
# 7                 ideditor:walkthrough_completed              1
# 8                  ideditor:walkthrough_progress              8
# 9                   ideditor:walkthrough_started              1
# 10                                  imagery_used             73
# 11                                      hashtags             37
# 12      resolved:almost_junction:highway-highway              1
# 13                                     data_used              2
# ...

# %%
df_tags['hashtags'].unique()
# Out:
# array([nan, '#hotosm-project-16817;#UNMappers;#UNMOGIP;#Jammu;#Kashmir',
#        '#geohealthresearch-project-26;#PivotscienceActivity', '#ola;#rdv',
#        '#irsju', '#hotosm-project-16875;#GeOSM;#PUC', '#adt',
#        '#hotosm-project-17137;#bloomberg;#emea',
#        '#hotosm-project-15229;#OSMIndia;#OSMNorthEastIndia;#GREd;#GREdFoundation;#AssamMapping23;#OMGuru;#APHub;#CCC2024;#tt_event',
#        '#BANO;#Pifometre', '#amap', '#tomtom;#tt_mapfeedback',
#        '#hotosm-project-14389;#MangochiDistrict;#msf;#missingmaps;#malawicholeraoutbreak',
#        '#maproulette', '#OpenCampingMap', '#lgmaps', '#swiggy',
#        '#PUC;#EST;#tt_event',
#        '#hotosm-project-15188;#Ndjamena;#msf;#missingmaps;#Ndjamena2023;#Msft;#24VR',
#        '#localknowledge;#grabosm',
#        '#hotosm-project-16259;#osmTaiwan;#NLSCopendata;#rivertracing',
#        '#MSFTOpenMaps',
#        '#hotosm-project-17266;#UPMAPPERS;#WAFARI;#YouthMappers;#SouthAfrica;#ESADisasterResponse',
# ...

# %% [markdown]
# ### For the "unique" unique values (=1), what are they for each key ?

# %%
# list of tags with only 1 unique value
l_1 = list(df_uniques['tag'][df_uniques['unique_values'] == 1])
l_1[-5:] # last five
# Out:
# ['answer',
#  'warnings:close_nodes:vertices',
#  'resolved:crossing_ways:highway-highway',
#  'warnings:outdated_tags:noncanonical_brand',
#  'resolved:crossing_ways:building-building']

# %%
df_tags['create'][~df_tags['create'].isna()]
# Out:
# 352    1
# 838    1
# Name: create, dtype: object

# %%
# show df for lines 352 and 838 : two changesets concerned by the same tag (NaN for all other changesets)
df_tags.iloc[[352,838]].T
# Out:
#                                                                                             352  \
# comment                                       Adding data with #MapComplete for theme #ghost...
# created_by                                                                  MapComplete 0.44.13
# locale                                                                                    de-DE
# source                                                                                      NaN
# StreetComplete:quest_type                                                                   NaN
# changesets_count                                                                            NaN
# host                                                    https://mapcomplete.org/ghostbikes.html
# ideditor:walkthrough_completed                                                              NaN
# ideditor:walkthrough_progress                                                               NaN
# ...

# %%
df_tags['description'].value_counts().rename_axis('unique_values').reset_index(name='count')
# Out:
#                                        unique_values  count
# 0  https://wiki.openstreetmap.org/wiki/Automated_...      2

# %% [markdown]
# ### DataFrame that sums up the occurrence of each unique uniques (unique values == 1)

# %%
df_tags[l_1].apply(pd.Series.value_counts).rename_axis('unique unique_values').T
# Out:
# unique unique_values                            1   10    2  3820706    4  \
# ideditor:walkthrough_completed                NaN  NaN  NaN      NaN  NaN
# ideditor:walkthrough_started                  NaN  NaN  NaN      NaN  NaN
# resolved:almost_junction:highway-highway      1.0  NaN  NaN      NaN  NaN
# resolved:help_request:fixme_tag               3.0  NaN  NaN      NaN  NaN
# resolved:mismatched_geometry:point_as_vertex  2.0  NaN  NaN      NaN  NaN
# resolved:close_nodes:vertices                 NaN  NaN  1.0      NaN  NaN
# warnings:missing_tag:descriptive              1.0  NaN  NaN      NaN  NaN
# bundle_id                                     NaN  NaN  NaN      NaN  NaN
# warnings:crossing_ways:building-highway       1.0  NaN  NaN      NaN  NaN
# closed:note                                   NaN  NaN  NaN      1.0  NaN
# warnings:almost_junction:highway-highway      3.0  NaN  NaN      NaN  NaN
# fixing_osm_roads                              NaN  NaN  NaN      NaN  NaN
# ...

# %% [markdown]
# ### Get changeset counts via fetching .osm.gz files

# %%
def urlized_sequence_number(sequence_number):
    # returns url of the form https://planet.osm.org/replication/changesets/123/456/789.osm.gz
    sequence_number_adjusted = str(sequence_number).rjust(9, "0")
    return f"https://planet.osm.org/replication/changesets/{sequence_number_adjusted[0:3]}/{sequence_number_adjusted[3:6]}/{sequence_number_adjusted[6:9]}.osm.gz"

# %%
sequence_number = 6191420

url_sequence = urlized_sequence_number(sequence_number)
url_sequence
# Out:
# 'https://planet.osm.org/replication/changesets/006/191/420.osm.gz'

# %%
import requests
import xml.etree.ElementTree as ET
import gzip
xml_sequence_request = requests.get(url_sequence, stream=True).raw.read()
xml_sequence = ET.fromstring(gzip.decompress(xml_sequence_request))
xml_sequence
# Out:
# <Element 'osm' at 0x11255def0>

# %%
# extract number of changesets in xml_sequence:

len(xml_sequence)
# Out:
# 61

# %%
# checking all the unique names of elements in the xml tree

for elem in xml_sequence:
    if elem.tag != 'changeset':
        print(elem.tag)

# %%
# check for many sequences if there are elements in xml other than 'changeset'ET

sequence_numbers = range(6191400, 6191420)

tags_not_changeset = {}
for sequence_number in sequence_numbers:
    tags_not_changeset[sequence_number] = []
    url_sequence = urlized_sequence_number(sequence_number)
    xml_sequence_request = requests.get(url_sequence, stream=True).raw.read()
    xml_sequence = ET.fromstring(gzip.decompress(xml_sequence_request))
    for elem in xml_sequence:
        if elem.tag != 'changeset':
            print(elem.tag)
            tags_not_changeset[sequence_number].append(elem.tag)

print(tags_not_changeset)
# Out:
# {6191400: [], 6191401: [], 6191402: [], 6191403: [], 6191404: [], 6191405: [], 6191406: [], 6191407: [], 6191408: [], 6191409: [], 6191410: [], 6191411: [], 6191412: [], 6191413: [], 6191414: [], 6191415: [], 6191416: [], 6191417: [], 6191418: [], 6191419: []}

# %%
def get_last_sequence():
    import yaml, requests
    """Fetches the latest sequence from the state.yaml file."""
    response = requests.get("https://planet.osm.org/replication/changesets/state.yaml", stream=True)
    last_sequence = int(yaml.load(response.raw.read(), Loader=yaml.FullLoader)["sequence"])
    return last_sequence

# %%
def get_changeset_count(sequence):
    """ Fetches changesets using urlized sequence number and extract the length of the xml tree <=> nb of changesets """
    url_sequence = urlized_sequence_number(sequence)
    xml_sequence_request = requests.get(url_sequence, stream=True).raw.read()
    xml_sequence = ET.fromstring(gzip.decompress(xml_sequence_request))
    return len(xml_sequence)

# %%
last_fetched_sequence = None

def update_changeset_view():
    global last_fetched_sequence
    new_sequence = get_last_sequence()
    # Check if the new sequence is different from the previous one
    if new_sequence != last_fetched_sequence:
        changeset_count = get_changeset_count(new_sequence)
        print(changeset_count)
        last_fetched_sequence = new_sequence  # Update the last fetched sequence
        return {"sequence": new_sequence, "changeset_count": changeset_count}

    # If there's no new sequence, return an empty response to avoid updating
    return {"sequence": last_fetched_sequence, "changeset_count": None}

update_changeset_view()
# Out:
# 36
# {'sequence': 6191463, 'changeset_count': 36}

# %%
type(get_changeset_count(6191457))
# Out:
# int

# %%
def get_last_sequence_test():
    import yaml, requests
    """Fetches the latest sequence from the state.yaml file."""
    response = requests.get("https://planet.osm.org/replication/changesets/state.yaml", stream=True)
    last_sequence = int(yaml.load(response.raw.read(), Loader=yaml.FullLoader)["sequence"])
    last_run = yaml.load(response.raw.read(), Loader=yaml.FullLoader)["last_run"]
    return last_sequence, last_run

# %%
def get_sequence_timestamp(sequence):
    # fetch https://planet.osm.org/replication/changesets/123/456/789
    sequence_number_adjusted = str(sequence_number).rjust(9, "0")
    url = f"https://planet.osm.org/replication/changesets/{sequence_number_adjusted[0:3]}/{sequence_number_adjusted[3:6]}/{sequence_number_adjusted[6:9]}"
# Out:
# ('https://planet.osm.org/replication/changesets/006/191/463.osm.gz',
#  'https://planet.osm.org/replication/changesets/006/191/463.state.text')

# %%
import requests
from bs4 import BeautifulSoup

def extract_timestamps(url, number_range):
    # Fetch the HTML content from the URL
    response = requests.get(url)
    html_content = response.text

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')

    # Initialize a dictionary to store the timestamps
    timestamps = {}

    # Loop through the anchor tags
    for a_tag in soup.find_all('a', href=True):
        href = a_tag['href']
        # Check if the href contains a number in the specified range followed by ".state.txt"
        if href.endswith('.state.txt'):
            number = int(href.split('.')[0])
            if number in number_range:
                # Extract the timestamp from the next sibling text
                timestamp = a_tag.find_next_sibling(text=True).strip().split()[:2]
                timestamps[number] = timestamp

    return timestamps

# Example usage
url = 'https://planet.osm.org/replication/changesets/006/191/'  # Replace with the actual URL
number_range = range(416, 421)  # Specify the range of numbers
timestamps = extract_timestamps(url, number_range)

# Print the extracted timestamps
for number, timestamp in timestamps.items():
    print(f"Number: {number}, Timestamp: {timestamp}")
# Out:
# Number: 420, Timestamp: ['2024-09-22', '08:23']
# Number: 419, Timestamp: ['2024-09-22', '08:22']
# Number: 418, Timestamp: ['2024-09-22', '08:21']
# Number: 417, Timestamp: ['2024-09-22', '08:20']
# Number: 416, Timestamp: ['2024-09-22', '08:19']
# /var/folders/n_/b2v5x65d6fvgkr8svqh31qww0000gn/T/ipykernel_55875/539943160.py:23: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   timestamp = a_tag.find_next_sibling(text=True).strip().split()[:2]

# %%
timestamps[420].split()[:2]
# Out:
# ['2024-09-22', '08:23']

# %%
sequence = 6191497
sequence_last_3 = int(str(sequence)[-3:])
print(sequence_last_3)
# Out:
# 497

# %%
sequence_adjusted = str(sequence_number).rjust(9, "0")
url = f"https://planet.osm.org/replication/changesets/{sequence_adjusted[0:3]}/{sequence_adjusted[3:6]}/"
response = requests.get(url)
html_content = response.text
soup = BeautifulSoup(html_content, 'html.parser')

# %%
soup.find_all('a', href=True)
# Out:
# [<a href="?C=N;O=A">Name</a>,
#  <a href="?C=M;O=A">Last modified</a>,
#  <a href="?C=S;O=A">Size</a>,
#  <a href="?C=D;O=A">Description</a>,
#  <a href="/replication/changesets/006/">Parent Directory</a>,
#  <a href="747.state.txt">747.state.txt</a>,
#  <a href="747.osm.gz">747.osm.gz</a>,
#  <a href="746.state.txt">746.state.txt</a>,
#  <a href="746.osm.gz">746.osm.gz</a>,
#  <a href="745.state.txt">745.state.txt</a>,
#  <a href="745.osm.gz">745.osm.gz</a>,
#  <a href="744.state.txt">744.state.txt</a>,
#  <a href="744.osm.gz">744.osm.gz</a>,
#  <a href="743.state.txt">743.state.txt</a>,
#  <a href="743.osm.gz">743.osm.gz</a>,
#  <a href="742.state.txt">742.state.txt</a>,
#  <a href="742.osm.gz">742.osm.gz</a>,
#  <a href="741.state.txt">741.state.txt</a>,
#  <a href="741.osm.gz">741.osm.gz</a>,
#  <a href="740.state.txt">740.state.txt</a>,
#  <a href="740.osm.gz">740.osm.gz</a>,
#  <a href="739.state.txt">739.state.txt</a>,
#  <a href="739.osm.gz">739.osm.gz</a>,
# ...

# %%
a_list = []
for a_tag in soup.find_all('a', href=True):
    href = a_tag['href']
    if href.endswith('.state.txt'):
        number = int(href.split('.')[0])
        sequence_last_3 = int(str(sequence)[-3:])
        if number in range(sequence_last_3 - 10, sequence_last_3):
            a_list.append(a_tag)

# %%
a_list[0].find_next_sibling(string=True)
# Out:
# '                2024-09-22 09:41   69   \n'

# %%
def scrape_timestamps(sequence, n_range=10):
    """Scrapes the timestamps of the last n_range changesets"""
    sequence_adjusted = str(sequence_number).rjust(9, "0")
    url = f"https://planet.osm.org/replication/changesets/{sequence_adjusted[0:3]}/{sequence_adjusted[3:6]}/"
    response = requests.get(url)
    html_content = response.text
    soup = BeautifulSoup(html_content, 'html.parser')
    timestamps = {}

    for a_tag in soup.find_all('a', href=True):
        href = a_tag['href']
        if href.endswith('.state.txt'):
            number = int(href.split('.')[0])
            sequence_last_3 = int(str(sequence)[-3:])
            if number in range(sequence_last_3 - n_range + 1, sequence_last_3 + 1):
                timestamp = a_tag.find_next_sibling(string=True).strip().split()[:2]
                timestamps[number] = timestamp
    return timestamps

timestamps = scrape_timestamps(6191770)

# %%
sequence_number = 6191770
print(f'timestamps dict : {timestamps}, length : {len(timestamps)}')
print(int(str(sequence_number)[-3:]), type(int(str(sequence_number)[-3:])))
timestamps[int(str(sequence_number)[-3:])][1]
# Out:
# timestamps dict : {770: ['2024-09-22', '14:24'], 769: ['2024-09-22', '14:23'], 768: ['2024-09-22', '14:21'], 767: ['2024-09-22', '14:20'], 766: ['2024-09-22', '14:19'], 765: ['2024-09-22', '14:18'], 764: ['2024-09-22', '14:17'], 763: ['2024-09-22', '14:16'], 762: ['2024-09-22', '14:15'], 761: ['2024-09-22', '14:14']}, length : 10
# 770 <class 'int'>
# '14:24'
